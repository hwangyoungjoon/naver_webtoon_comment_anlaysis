# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from urllib.parse import urlparse, parse_qs, urljoin

# %%
url="http://comic.naver.com/comment/comment.nhn?titleId=686312&no=55"
chromedriver="./chromedriver"

driver=webdriver.Chrome(chromedriver)
driver.implicitly_wait(3)
driver.get(url)
all_coments=driver.find_element_by_class_name("u_cbox_sort_option_wrap")
all_coments.click()

# %%
for a in content:
    print (a.text)
# Out:
# BEST답답해 하지만 이해해
# BEST아..이게현실이었지
# BEST사이다 타령하는 것들은 사회생활 1도 안해보셨나봐? 니들 일어날수 있는일도 대놓고 판타지로 바꾸라네ㅋㅋㅋㄱㅋ
# BEST조옵쌀 샌드백 인형 안 나오나요? 회사에 조옵쌀같이 행동하는 상사 있는데 그 인간 생각하면서 때리고 싶네요 직장인 스트레스 해소용 인형으로 나왔으면..
# BEST아 속상해ㅠㅠㅜㅠ 여주 기운을 내 제발
# BEST용기가 없는게 아니라 현실이 너의 용기를 누르고있는거야
# BEST진짜 제목이랑 똑같다....열정호구
# BEST소연이 캐릭터 답게 조곤조곤한 독백이 독자로 하여금 자연스레 이입하게 하네요.. 소연이 마음 아파하는 모습 보면 저도 힘들어요..ㅠㅠ
# BEST오늘 직원들끼리 야근하던 도중 얘기가 나와서 단체로 태업을 진행하려다 포기했습니다. 반대를 얘기한 사람 중에 제 자신이 있다는 게 너무 부끄럽더군요. 회사 사정이란 이유로 돈도 나오지 않는 무리한 야근이 계속되고, 다들 근로의욕도 떨어지는 건 알고 있습니다. 때론 무의미하게 혹은 무리하게 남아서 효율만 떨어뜨리는 야근이 옳지 않은 것도 알고요. 그러나 누군가에겐, 특히 저에겐 잘리면 안 되는 직장이라 조용히 반대를 말할 수 밖에 없었고, 다른 직원들도 이해와 공감은 했지만 내가 배신자 혹은 다른 직원들의 발목을 잡는 존재가 되었다는 생각에 씁쓸함이 가시지 않습니다... 그러네요. 저도 열정호구에요.
# BEST여태본웹툰중에 가장현실적..
# BEST전 직장 사내게시판에 해우소라는 게 있었다. 못 하는 이야기를 올리라고 만들었댔지. 어느날 해우소에 상사를 질책하는 글이 올라왔다. 회사는 당연히 그 글을 지우고, 추적하고 징계했다.  이번엔 또 다른 이야기다. 회사가 쓰레기 같아서 퇴직 후에 후배가 회사를 비판하는 글을 취업사이트에 올렸다. 그러자 회사측에서 후배에게 연락이 왔다. 글을 내리지 않으면 고소한단다. 그렇다. 취업사이트에 있는 이 회사 좋아요? 믿지마. 진짜 그 회사 그 부서에 다니는 사람에게 꼭 물어봐라. 진짜인지 아닌지.
# BEST사실 슬프지만 이 문화를 같이 만들어가는데 일조한 셈이되는거다.. 중립그리고 침묵은 나도 거기이 동조했다는 뜻이야..
# BEST저게 현실.... 소연이 발암이다 답답하다 뭐다하지만 막상 본인들도 소연이상황에 있으면 그렇게 행동하게 될걸요ㅠㅠ
# BEST솔직히 소연이 용기없고 그럴때마다 엄마 아빠 잘못이라는 생각이 든다. 부모부터 제대로 대우해줬어야 하는데....힘내라!!!
# BEST조옵쌀 샌드백인형 만들어주세요 꼭삽니다

# %%
url="http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=55&weekday=tue"
chromedriver="./chromedriver"

driver=webdriver.Chrome(chromedriver)
driver.implicitly_wait(3)
driver.get(url)
find_element_by_xpath('//*[@id="frmNIDLogin"]/fieldset/input').click()
html=driver.page_source 
soup=BeautifulSoup(html,"lxml",from_encoding="utf-8")

content=soup.find("iframe",attrs={"id":{"commentIframe"}})


driver.quit()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:146: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
content
# Out:
# <iframe frameborder="0" id="commentIframe" scrolling="no" src="/comment/comment.nhn?titleId=686312&amp;no=55" style="min-height: 500px; height: 2130px;" title="열정호구 - 54화 야망가 (3) 댓글영역" width="100%"></iframe>

# %%
def get_daylywebtoons():
    '''
    요일 웹툰을 수집
    '''
    webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
    naver_url='http://comic.naver.com'
    res = requests.get(webtoon_main_url)
    main_soup = BeautifulSoup(res.content, 'lxml')
 
    
 
    return webtoon_links

# %%
b=get_daylywebtoons()

# %%
urljoin(naver_url, a_tag.get('href'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-123927445428> in <module>()
# ----> 1 urljoin(naver_url, a_tag.get('href'))
#
# NameError: name 'naver_url' is not defined

# %%
webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
naver_url='http://comic.naver.com'
res = requests.get(webtoon_main_url)
main_soup = BeautifulSoup(res.content, 'lxml')

# %%
webtoon_links = [{"title": a_tag.get('title'), "link": urljoin(naver_url, 
                                                                 a_tag.get('href'))}
                      for a_tag in main_soup.select('.daily_all a.title')]

# %%
  for a_tag in main_soup.select('.daily_all a.title'):
        print (a_tag.get("title"))
# Out:
# 신의 탑
# 뷰티풀 군바리
# 윈드브레이커
# 선천적 얼간이들 (재)
# 대학일기
# 귀전구담
# 평범한 8반
# 소녀의 세계
# 이것도 친구라고
# 마왕이 되는 중2야
# 가우스전자 시즌3
# 환생동물학교
# 하루 3컷
# 닥터 하운드
# 마이너스의 손
# 퓨어 이블
# 이상하고 아름다운
# 마루한 - 구현동화전
# 꿈의 기업
# 심연의 하늘 시즌5
# 탈(TAL)
# 히어로메이커
# 팀피닉스
# 찬란하지 않아도 괜찮아
# 마음의소리
# 노블레스
# 하이브3
# 오!주예수여
# 원주민 공포만화
# 슈퍼 시크릿
# 덴마
# 빙탕후루
# 신도림
# 놓지마 정신줄 시즌2
# 가우스전자 시즌3
# 데모니악
# 제로게임
# 하루 3컷
# 윌유메리미
# 오늘부터 주군
# 공감.jpg
# 에이머
# 열정호구
# 모태솔로수용소 시즌2~3
# 미스터리 호러 지하철 (재)
# 첩보의 별 시즌2
# 패밀리 사이즈
# 기로
# 간질간질
# 복학왕
# 고수
# 연놈
# 헬퍼 2 : 킬베로스
# 목욕의 신 (재)
# 유미의 세포들
# 미시령
# 조선왕조실톡
# 퍼스트 미션
# DEY 호러채널
# 가우스전자 시즌3
# 언덕 위의 제임스
# 돌아온 럭키짱
# 야채호빵의 봄방학
# 하루 3컷
# 그 판타지 세계에서 사는 법
# 지금 이 순간 마법처럼
# 고민툰
# 격기 3반
# 씬커
# Penguin loves Mev
# 푸른사막 아아루
# 칼부림
# 달콤한 인생_스페셜 에피소드
# 10월 28일
# 섬나라 메생이국
# 연애혁명
# 신과함께 (재)
# 기기괴괴
# 대학일기
# 좋아하는 부분
# 최강전설 강해효
# 쿠베라
# 간 떨어지는 동거
# 전자오락수호대
# 이 편의점 실화냐?
# 가우스전자 시즌3
# 가담항설
# 마술사
# 하루 3컷
# 계룡선녀전
# Doll 체인지
# 파도의 주인
# 서북의 저승사자
# 하나의 하루
# 백귀야행지
# 에피소드칵테일
# 아일랜드 2부
# 트롤트랩
# 우리집에 곰이 이사왔다
# 킬더킹
# 천국의 신화 6부
# 특수 영능력 수사반
# 동네변호사 조들호 시즌2
# 외모지상주의
# 갓 오브 하이스쿨
# 쌉니다 천리마마트 (재)
# 한번 더 해요
# 덴마
# 밥 먹고 갈래요?
# 걸어서 30분
# 결계녀
# 테러맨
# 더 게이머
# 가우스전자 시즌3
# 공대생 너무만화
# 하루 3컷
# 스위트홈
# 연애학
# 아테나 컴플렉스
# 골든 체인지
# 조선좀비실록
# 피에는 피
# 강변살다
# 그들에게 사면초가
# 몽홀
# 이별만화 완성도
# 고민툰
# 르완 多 한 컷
# Penguin loves Mev
# 킬러 김빵빵
# 진눈깨비 소년
# 프리드로우
# 용이산다
# 호랑이형님
# 내 ID는 강남미인!
# 부활남
# 금수저
# 공복의 저녁식사
# 나노리스트
# 대가리
# 유미의 세포들
# 야부리맨
# 놓지마 정신줄 시즌2
# 우리 오빠는 아이돌
# 인간의 숲 (재)
# 아메리카노 엑소더스
# 귀각시
# 하루 3컷
# 갸오오와 사랑꾼들
# 윌유메리미
# 나이트런
# 공감.jpg
# 트럼프
# 첩보의 별 시즌2
# 구름의 이동속도
# 네버랜 연대기
# 달콤한 인생_스페셜 에피소드
# 조의 영역
# 스피릿 핑거스
# 열렙전사
# 다이스(DICE)
# 언원티드
# 구구까까
# 연애의 정령
# 덴마
# 조선왕조실톡
# 오늘도 사랑스럽개
# 뱀이 앉은 자리
# 마법스크롤상인 지오
# 하루 3컷
# 썬데이 상담소
# 심심한 마왕
# 감염자
# 마스크걸
# 호랭총각
# 도망자
# 허니허니 웨딩
# 귀도호가록
# 내일
# 웅이는 배고파
# 오늘도 핸드메이드!
# 패밀리 사이즈

# %%
  for webtoon in b:
        target_webtoons = get_all_webtoon(webtoon, False)
        print(tatget_webtoons)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-989da2d7d528> in <module>()
#       1 for webtoon in b:
# ----> 2       target_webtoons = get_all_webtoon(webtoon, False)
#       3       print(tatget_webtoons)
#
# NameError: name 'get_all_webtoon' is not defined

# %%
webpage = webdriver.Chrome(chromedriver)
webpage.get(url)

#넥스트 버튼을 찾아온다.
next_button = self.find_child_page_next_button(commentID, webpage)

#넥스트 버튼이없으면 반복문 종료
if not next_button: break

#있으면 버튼 클릭
next_button.click()            

#버튼 클릭
def find_child_page_next_button(self, parentID, webpage):
    try:
        child_next_button = webpage.find_element_by_xpath(
            '//li[contains(@data-info,"'+ parentID +'")]//a[@class="u_cbox_next"]')
    except NoSuchElementException:
        return None

    return child_next_button
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-0d1b2ae5a31c> in <module>()
#       3
#       4 #넥스트 버튼을 찾아온다.
# ----> 5 next_button = self.find_child_page_next_button(commentID, webpage)
#       6
#       7 #넥스트 버튼이없으면 반복문 종료
#
# NameError: name 'self' is not defined

# %%
import requests 
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urljoin
import json

# %%
def save(data, file_name):
    file=open(file_name,"a")
    file.write(data+"\n")
    
    
def get_daylywebtoons():
    '''
    요일 웹툰을 수집
    '''
    webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
    naver_url='http://comic.naver.com'
    res = requests.get(webtoon_main_url)
    main_soup = BeautifulSoup(res.content, 'lxml')
 
    webtoon_links = [{"title": a_tag.get('title'), "link": urljoin(naver_url, a_tag.get('href'))}
                      for a_tag in main_soup.select('.daily_all a.title')]
 
    return webtoon_links


def make_link(webtoon_url, page_count):
    return webtoon_url + '&page=' + str(page_count)


def get_all_webtoon(webtoon,is_save):
    webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
    naver_url='http://comic.naver.com'
    page_count=1
    is_unlast=True
    
    target_webtoons=list()
    webtoon_url=webtoon["link"]
    webtoon_title=webtoon["title"]
    
    while is_unlast:
        link=make_link(webtoon_url,page_count)
        target_webtoon_res=requests.get(link)
        webtoon_soup=BeautifulSoup(target_webtoon_res.content,'lxml')
        a_tags=webtoon_soup.select(".viewList td.title a")
        #클래스가 viewlist-> td 클래스가 title -> a태그
        #그페이지에 있는 웹툰  차수
        for a_tag in a_tags:
            t=a_tag.text.replace("\n","").replace('\r', '').replace('\t', '')
            #웹툰차수
            h=urljoin(naver_url,a_tag.get("href"))
            #웹툰차수링크
            if h not in target_webtoons:
                target_webtoons.append(h)
            else:
                is_unlast=False
                
        page_count += 1  
        
    if is_save:
        for webtoon in target_webtoons:
            save(webtoon_title+":"+webtoon,"all_webtoons.txt")
                
    return target_webtoons

def data_parse(soup,url):
    rank = soup.select('#topPointTotalNumber')[0].text #r그 회차 별점
    print(rank)
    title = soup.title.text.split(':')[0]  # 웹툰 제목
    print(title)
    titleId =str( parse_qs(urlparse(url).query)['titleId'][0]) #웹툰 고유아이디값
    print(titleId)
    no = str(parse_qs(urlparse(url).query)['no'][0])# 웹툰 그 회차 페이지
    print(no)
    
    comment_url = 'http://comic.naver.com' + '/comment/comment.nhn?titleId=' + titleId + '&no=' + no
    objectId = titleId + '_' + no
    
    
    page_count = 1
 
    u = 'http://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery1113012327623800394427_1489937311100&lang=ko&country=KR&objectId=' +objectId+ '&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&sort=NEW&_=1489937311112'
 
   
    while True:
        comment_url = make_link(u, page_count)
        header = {
            "Host": "apis.naver.com",
            "Referer": "http://comic.naver.com/comment/comment.nhn?titleId=" + titleId + "&no=" + no,
            "Content-Type": "application/javascript"
        }
        
        res = requests.get(comment_url, headers = header)
        soup = BeautifulSoup(res.content, 'lxml')
        try:
            content_text = soup.select('p')[0].text
            one = content_text.find('(') + 1
            two = content_text.find(');')
            content = json.loads(content_text[one:two])

            comments = content['result']['commentList']

            print(titleId, no)

            for comment in comments:
                print(comment['contents'])

            if not len(comments):
                break
            else:
                page_count += 1
        except:
            pass

# %%
b=get_daylywebtoons()
c=get_all_webtoon(b[0],False)

# %%
b
# Out:
# [{'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=183559&weekday=mon',
#   'title': '신의 탑'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=648419&weekday=mon',
#   'title': '뷰티풀 군바리'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=602910&weekday=mon',
#   'title': '윈드브레이커'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697680&weekday=mon',
#   'title': '선천적 얼간이들 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679519&weekday=mon',
#   'title': '대학일기'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694946&weekday=mon',
#   'title': '귀전구담'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=597478&weekday=mon',
#   'title': '평범한 8반'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=654774&weekday=mon',
#   'title': '소녀의 세계'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=698888&weekday=mon',
#   'title': '이것도 친구라고'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694807&weekday=mon',
#   'title': '마왕이 되는 중2야'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=700139&weekday=mon',
#   'title': '환생동물학교'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675554&weekday=mon',
#   'title': '가우스전자 시즌3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=700858&weekday=mon',
#   'title': '닥터 하운드'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=mon',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679568&weekday=mon',
#   'title': '마이너스의 손'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694191&weekday=mon',
#   'title': '퓨어 이블'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=668723&weekday=mon',
#   'title': '이상하고 아름다운'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702170&weekday=mon',
#   'title': '심연의 하늘 시즌5'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=624632&weekday=mon',
#   'title': '마루한 - 구현동화전'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=687915&weekday=mon',
#   'title': '꿈의 기업'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=316911&weekday=mon',
#   'title': '탈(TAL)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=21815&weekday=mon',
#   'title': '히어로메이커'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=698247&weekday=mon',
#   'title': '찬란하지 않아도 괜찮아'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=658076&weekday=mon',
#   'title': '팀피닉스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=20853&weekday=tue',
#   'title': '마음의소리'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=25455&weekday=tue',
#   'title': '노블레스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675331&weekday=tue',
#   'title': '하이브3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=655744&weekday=tue',
#   'title': '오!주예수여'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=698918&weekday=tue',
#   'title': '원주민 공포만화'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=650304&weekday=tue',
#   'title': '슈퍼 시크릿'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=119874&weekday=tue',
#   'title': '덴마'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=695321&weekday=tue',
#   'title': '빙탕후루'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=683496&weekday=tue',
#   'title': '신도림'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=682637&weekday=tue',
#   'title': '놓지마 정신줄 시즌2'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675554&weekday=tue',
#   'title': '가우스전자 시즌3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=692512&weekday=tue',
#   'title': '데모니악'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=676695&weekday=tue',
#   'title': '제로게임'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=tue',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=616239&weekday=tue',
#   'title': '윌유메리미'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=695768&weekday=tue',
#   'title': '오늘부터 주군'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686911&weekday=tue',
#   'title': '공감.jpg'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=400739&weekday=tue',
#   'title': '에이머'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686312&weekday=tue',
#   'title': '열정호구'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=666670&weekday=tue',
#   'title': '모태솔로수용소 시즌2~3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=700361&weekday=tue',
#   'title': '미스터리 호러 지하철 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686669&weekday=tue',
#   'title': '첩보의 별 시즌2'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=626906&weekday=tue',
#   'title': '패밀리 사이즈'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=653344&weekday=tue',
#   'title': '기로'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702165&weekday=tue',
#   'title': '간질간질'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=626907&weekday=wed',
#   'title': '복학왕'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=662774&weekday=wed',
#   'title': '고수'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=667573&weekday=wed',
#   'title': '연놈'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670143&weekday=wed',
#   'title': '헬퍼 2 : 킬베로스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697681&weekday=wed',
#   'title': '목욕의 신 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=651673&weekday=wed',
#   'title': '유미의 세포들'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697533&weekday=wed',
#   'title': '미시령'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=642598&weekday=wed',
#   'title': '조선왕조실톡'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675554&weekday=wed',
#   'title': '가우스전자 시즌3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694131&weekday=wed',
#   'title': '퍼스트 미션'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=449854&weekday=wed',
#   'title': '돌아온 럭키짱'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=696593&weekday=wed',
#   'title': 'DEY 호러채널'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=671421&weekday=wed',
#   'title': '언덕 위의 제임스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=wed',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694806&weekday=wed',
#   'title': '야채호빵의 봄방학'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701535&weekday=wed',
#   'title': '격기 3반'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=316909&weekday=wed',
#   'title': '그 판타지 세계에서 사는 법'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=681453&weekday=wed',
#   'title': '지금 이 순간 마법처럼'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701699&weekday=wed',
#   'title': '달콤한 인생_스페셜 에피소드'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=699413&weekday=wed',
#   'title': '고민툰'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=635174&weekday=wed',
#   'title': '씬커'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702423&weekday=wed',
#   'title': '10월 28일'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=169080&weekday=wed',
#   'title': 'Penguin loves Mev'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697254&weekday=wed',
#   'title': '푸른사막 아아루'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=602916&weekday=wed',
#   'title': '칼부림'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702463&weekday=wed',
#   'title': '지캠단편 2017'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702435&weekday=wed',
#   'title': '섬나라 메생이국'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=570503&weekday=thu',
#   'title': '연애혁명'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697685&weekday=thu',
#   'title': '신과함께 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=557672&weekday=thu',
#   'title': '기기괴괴'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679519&weekday=thu',
#   'title': '대학일기'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=699659&weekday=thu',
#   'title': '좋아하는 부분'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=570506&weekday=thu',
#   'title': '최강전설 강해효'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=699415&weekday=thu',
#   'title': '간 떨어지는 동거'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=131385&weekday=thu',
#   'title': '쿠베라'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=637931&weekday=thu',
#   'title': '전자오락수호대'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675554&weekday=thu',
#   'title': '가우스전자 시즌3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=24965&weekday=thu',
#   'title': '마술사'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670144&weekday=thu',
#   'title': '가담항설'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=thu',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701700&weekday=thu',
#   'title': '트롤트랩'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=693431&weekday=thu',
#   'title': '계룡선녀전'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=693444&weekday=thu',
#   'title': 'Doll 체인지'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=579352&weekday=thu',
#   'title': '에피소드칵테일'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=652418&weekday=thu',
#   'title': '파도의 주인'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=694805&weekday=thu',
#   'title': '하나의 하루'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=657948&weekday=thu',
#   'title': '서북의 저승사자'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=646358&weekday=thu',
#   'title': '백귀야행지'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=687921&weekday=thu',
#   'title': '아일랜드 2부'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=690594&weekday=thu',
#   'title': '우리집에 곰이 이사왔다'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670145&weekday=thu',
#   'title': '킬더킹'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670131&weekday=thu',
#   'title': '천국의 신화 6부'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=160469&weekday=thu',
#   'title': '특수 영능력 수사반'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675829&weekday=thu',
#   'title': '동네변호사 조들호 시즌2'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=641253&weekday=fri',
#   'title': '외모지상주의'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=318995&weekday=fri',
#   'title': '갓 오브 하이스쿨'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697679&weekday=fri',
#   'title': '쌉니다 천리마마트 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675393&weekday=fri',
#   'title': '한번 더 해요'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=119874&weekday=fri',
#   'title': '덴마'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=651664&weekday=fri',
#   'title': '밥 먹고 갈래요?'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701081&weekday=fri',
#   'title': '스위트홈'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=668101&weekday=fri',
#   'title': '결계녀'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=700844&weekday=fri',
#   'title': '걸어서 30분'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670149&weekday=fri',
#   'title': '테러맨'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675554&weekday=fri',
#   'title': '가우스전자 시즌3'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=678499&weekday=fri',
#   'title': '공대생 너무만화'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=fri',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=552960&weekday=fri',
#   'title': '더 게이머'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=696602&weekday=fri',
#   'title': '연애학'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679543&weekday=fri',
#   'title': '아테나 컴플렉스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=685460&weekday=fri',
#   'title': '골든 체인지'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=509094&weekday=fri',
#   'title': '조선좀비실록'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=696617&weekday=fri',
#   'title': '피에는 피'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=578108&weekday=fri',
#   'title': '강변살다'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=693429&weekday=fri',
#   'title': '그들에게 사면초가'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644112&weekday=fri',
#   'title': '몽홀'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=654333&weekday=fri',
#   'title': '이별만화 완성도'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=699413&weekday=fri',
#   'title': '고민툰'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=677753&weekday=fri',
#   'title': '킬러 김빵빵'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=169080&weekday=fri',
#   'title': 'Penguin loves Mev'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701054&weekday=fri',
#   'title': '르완 多 한 컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=622643&weekday=fri',
#   'title': '진눈깨비 소년'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=597447&weekday=sat',
#   'title': '프리드로우'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=568986&weekday=sat',
#   'title': '용이산다'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=650305&weekday=sat',
#   'title': '호랑이형님'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=677536&weekday=sat',
#   'title': '내 ID는 강남미인!'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670139&weekday=sat',
#   'title': '부활남'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679567&weekday=sat',
#   'title': '금수저'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=642700&weekday=sat',
#   'title': '공복의 저녁식사'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670150&weekday=sat',
#   'title': '나노리스트'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=677737&weekday=sat',
#   'title': '대가리'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=651673&weekday=sat',
#   'title': '유미의 세포들'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=651665&weekday=sat',
#   'title': '야부리맨'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=682637&weekday=sat',
#   'title': '놓지마 정신줄 시즌2'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697654&weekday=sat',
#   'title': '인간의 숲 (재)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=622644&weekday=sat',
#   'title': '아메리카노 엑소더스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=700843&weekday=sat',
#   'title': '우리 오빠는 아이돌'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=679570&weekday=sat',
#   'title': '귀각시'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=sat',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670151&weekday=sat',
#   'title': '갸오오와 사랑꾼들'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=616239&weekday=sat',
#   'title': '윌유메리미'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=64997&weekday=sat',
#   'title': '나이트런'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686911&weekday=sat',
#   'title': '공감.jpg'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=524520&weekday=sat',
#   'title': '트럼프'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=701699&weekday=sat',
#   'title': '달콤한 인생_스페셜 에피소드'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686669&weekday=sat',
#   'title': '첩보의 별 시즌2'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=687137&weekday=sat',
#   'title': '구름의 이동속도'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=664406&weekday=sat',
#   'title': '네버랜 연대기'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=702463&weekday=sat',
#   'title': '지캠단편 2017'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697656&weekday=sun',
#   'title': '조의 영역'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=654809&weekday=sun',
#   'title': '스피릿 핑거스'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=670152&weekday=sun',
#   'title': '열렙전사'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=557676&weekday=sun',
#   'title': '다이스(DICE)'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=698469&weekday=sun',
#   'title': '언원티드'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=684435&weekday=sun',
#   'title': '구구까까'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=651617&weekday=sun',
#   'title': '연애의 정령'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=119874&weekday=sun',
#   'title': '덴마'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=699658&weekday=sun',
#   'title': '오늘도 사랑스럽개'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=642598&weekday=sun',
#   'title': '조선왕조실톡'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=655746&weekday=sun',
#   'title': '마법스크롤상인 지오'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=695585&weekday=sun',
#   'title': '뱀이 앉은 자리'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=644180&weekday=sun',
#   'title': '하루 3컷'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=675823&weekday=sun',
#   'title': '감염자'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=578125&weekday=sun',
#   'title': '썬데이 상담소'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=374974&weekday=sun',
#   'title': '심심한 마왕'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=660366&weekday=sun',
#   'title': '마스크걸'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=22897&weekday=sun',
#   'title': '호랭총각'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=690503&weekday=sun',
#   'title': '도망자'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697537&weekday=sun',
#   'title': '허니허니 웨딩'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=665170&weekday=sun',
#   'title': '귀도호가록'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=695796&weekday=sun',
#   'title': '내일'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=697535&weekday=sun',
#   'title': '웅이는 배고파'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686018&weekday=sun',
#   'title': '오늘도 핸드메이드!'},
#  {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=626906&weekday=sun',
#   'title': '패밀리 사이즈'}]

# %%
def save(data, file_name):
    file=open(file_name,"a")
    file.write(data+"\n")
    
    
def get_daylywebtoons():
    '''
    요일 웹툰을 수집
    '''
    webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
    naver_url='http://comic.naver.com'
    res = requests.get(webtoon_main_url)
    main_soup = BeautifulSoup(res.content, 'lxml')
 
    webtoon_links = [{"title": a_tag.get('title'), "link": urljoin(naver_url, a_tag.get('href'))}
                      for a_tag in main_soup.select('.daily_all a.title')]
 
    return webtoon_links


def make_link(webtoon_url, page_count):
    return webtoon_url + '&page=' + str(page_count)


def get_all_webtoon(webtoon,is_save):
    webtoon_main_url = 'http://comic.naver.com/webtoon/weekday.nhn'
    naver_url='http://comic.naver.com'
    page_count=1
    
    is_unlast=True
    
    target_webtoons=list()
    webtoon_url=webtoon["link"]
    webtoon_title=webtoon["title"]
    
 
    link=make_link(webtoon_url,page_count)
    target_webtoon_res=requests.get(link)
    webtoon_soup=BeautifulSoup(target_webtoon_res.content,'lxml')
    a_tags=webtoon_soup.select(".viewList td.title a")
        #클래스가 viewlist-> td 클래스가 title -> a태그
        #그페이지에 있는 웹툰  차수
    for a_tag in a_tags:
        t=a_tag.text.replace("\n","").replace('\r', '').replace('\t', '')
            #웹툰차수
        h=urljoin('http://comic.naver.com',a_tag.get("href"))
            #웹툰차수링크
        if h not in target_webtoons:
            target_webtoons.append(h)
        

    return target_webtoons
            
    
def data_parse(soup,url):
    rank = soup.select('#topPointTotalNumber')[0].text #r그 회차 별점
    print(rank)
    title = soup.title.text.split(':')[0]  # 웹툰 제목
    print(title)
    titleId =str( parse_qs(urlparse(url).query)['titleId'][0]) #웹툰 고유아이디값
    print(titleId)
    no = str(parse_qs(urlparse(url).query)['no'][0])# 웹툰 그 회차 페이지
    print(no)
    
    comment_url = 'http://comic.naver.com' + '/comment/comment.nhn?titleId=' + titleId + '&no=' + no
    objectId = titleId + '_' + no
    
    
    page_count = 1
 
    u = 'http://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery1113012327623800394427_1489937311100&lang=ko&country=KR&objectId=' +objectId+ '&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&sort=NEW&_=1489937311112'
 
   
    while True:
        comment_url = make_link(u, page_count)
        header = {
            "Host": "apis.naver.com",
            "Referer": "http://comic.naver.com/comment/comment.nhn?titleId=" + titleId + "&no=" + no,
            "Content-Type": "application/javascript"
        }
        
        res = requests.get(comment_url, headers = header)
        soup = BeautifulSoup(res.content, 'lxml')
        try:
            content_text = soup.select('p')[0].text
            one = content_text.find('(') + 1
            two = content_text.find(');')
            content = json.loads(content_text[one:two])

            comments = content['result']['commentList']

            print(titleId, no)

            for comment in comments:
                print(comment['contents'])

            if not len(comments):
                break
            else:
                page_count += 1
        except:
            pass

# %%
for num in b:
  if num.get("title")=="열정호구":
    print (num)
# Out:
# {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686312&weekday=tue', 'title': '열정호구'}

# %%
b[42]
# Out:
# {'link': 'http://comic.naver.com/webtoon/list.nhn?titleId=686312&weekday=tue',
#  'title': '열정호구'}

# %%
d=get_all_webtoon(b[42],False)

# %%
d
# Out:
# ['http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=55&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=54&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=53&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=52&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=51&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=50&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=49&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=48&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=47&weekday=tue',
#  'http://comic.naver.com/webtoon/detail.nhn?titleId=686312&no=46&weekday=tue']

# %%
d[0]
