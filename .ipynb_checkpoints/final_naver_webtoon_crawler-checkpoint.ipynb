# %%
from bs4 import BeautifulSoup
import numpy
import requests as res
from urllib.parse import urlparse, parse_qs, urljoin
import json
import openpyxl
import time
import random
import queue
import threading
random.seed(1287)


# daily webtoon

def crawler_daily_webtoon():
    get_daily_webtoon = res.get("http://comic.naver.com/webtoon/weekday.nhn")
    soup = BeautifulSoup(get_daily_webtoon.content, "lxml")
    tag = soup.select(".daily_all a.title")
    webtoon_list = [{"title": a.get("title"), "link": str("http://comic.naver.com") + a.get("href")} for a in tag]

    return webtoon_list


# all_episode

def cralwer_episode(webtoon):
    target_webtoon = list()
    page_num = 1
    is_unlast = True
    while is_unlast:
        link = webtoon["link"] + "&page=" + str(page_num)
        get_page = res.get(link)
        page = BeautifulSoup(get_page.content, "lxml")
        a_tags = page.select(".viewList td.title a")
        for a_tag in a_tags:
            episode = a_tag.text.replace("\n", "").replace("\r", "").replace("\t", "")
            episode_url = "http://comic.naver.com" + str(a_tag.get("href"))

            if episode_url not in target_webtoon:
                target_webtoon.append(episode_url)

            else:
                is_unlast = False

        page_num += 1
    return target_webtoon

def get_comments(soup, url):
        title = soup.title.text.split(':')[0]
        titleId = str(parse_qs(urlparse(url).query)['titleId'][0])  # 웹툰 고유아이디값
        no = str(parse_qs(urlparse(url).query)['no'][0])  # 웹툰 그 회차 페이지

        comment_url = 'http://comic.naver.com' + '/comment/comment.nhn?titleId=' + titleId + '&no=' + no
        objectId = titleId + '_' + no
        sub_title = soup.select(".tit_area h3")
        sub_title = sub_title[0].text
        page_count = 1

        u = 'http://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=comic&templateId=webtoon&pool=cbox3&_callback=jQuery1113012327623800394427_1489937311100&lang=ko&country=KR&objectId=' + objectId + '&categoryId=&pageSize=15&indexSize=10&groupId=&listType=OBJECT&sort=NEW&_=1489937311112'

        comment_list = list()

        while True:
            comment_url = u + "&page=" + str(page_count)
            header = {
                "Host": "apis.naver.com",
                "Referer": "http://comic.naver.com/comment/comment.nhn?titleId=" + titleId + "&no=" + no,
                "Content-Type": "application/javascript"
            }
            # time.sleep(random.uniform(0.3, 0.8))
            rq = res.get(comment_url, headers=header)

            soup = BeautifulSoup(rq.content, 'lxml')

            try:
                content_text = soup.select('p')[0].text
                one = content_text.find('(') + 1
                two = content_text.find(');')
                content = json.loads(content_text[one:two])

                comments = content['result']['commentList']

                for comment in comments:
                     comment_list.append({"sub_title":sub_title,
                                          "title": title,
                                          "comment":comment["contents"],
                                          "sympathy_count":comment["sympathyCount"],
                                          "episode_num":no})
                   #  print(comment["contents"])
                if not len(comments):
                    return comment_list
                    
                else:
                    page_count += 1
            except:
                print ("not found \t %10s %d page" % (sub_title,page_count))
                page_count += 1

# %%
class Input_Thread(threading.Thread):
    def __init__(self, input_queue, out_queue):
        threading.Thread.__init__(self)
        self.input_queue = input_queue
        self.out_queue = out_queue

    def run(self):
        while True:
            url = self.input_queue.get()
            #             rt=res.get(url)
            #             soup=BeautifulSoup(rt.content,"lxml")
            self.out_queue.put(url)

            self.input_queue.task_done()


class Output_Thread(threading.Thread):
    def __init__(self,out_queue,last_queue):
        threading.Thread.__init__(self)
        self.out_queue = out_queue
        self.last_queue=last_queue
    def run(self):
        while True:
            data = self.out_queue.get()
            rt = res.get(data)
            soup = BeautifulSoup(rt.content, "lxml")

            # print("[" + str(self.idx) + " : " + str(data) + "]")
            # time.sleep(random.uniform(2.1, 2.8))
            last_queue.put(get_comments(soup, data))
            self.last_queue.task_done()
            self.out_queue.task_done()

# %%
a=crawler_daily_webtoon()


fire_hogu=cralwer_episode(a[46])

input_queue=queue.Queue()
out_queue=queue.Queue()
last_queue=queue.Queue()


for i in fire_hogu[-3:]:

    th = Input_Thread(input_queue, out_queue)
    th.setDaemon(True)
    th.start()

for epi in fire_hogu:
    input_queue.put(epi)

for epi1 in range(3):
    out = Output_Thread(out_queue,last_queue)
    out.setDaemon(True)
    out.start()

input_queue.join()
out_queue.join()
last_queue.join()
# Out:
# not found    63화 5개월 1 page
# not found     62화 다짐 6 page
# not found     62화 다짐 11 page
# not found    63화 5개월 15 page
# not found     61화 분란 16 page
# not found     61화 분란 26 page
# not found     61화 분란 30 page
# not found     61화 분란 31 page
# not found     61화 분란 41 page
# not found    63화 5개월 42 page
# not found     61화 분란 60 page
# not found     61화 분란 62 page
# not found 60화 모범생 (2) 23 page
# not found 60화 모범생 (2) 24 page
# not found 60화 모범생 (2) 30 page
# not found 60화 모범생 (2) 39 page
# not found 60화 모범생 (2) 42 page
# not found     61화 분란 85 page
# not found 60화 모범생 (2) 48 page
# not found 59화 모범생 (1) 44 page
# not found     61화 분란 94 page
# not found 60화 모범생 (2) 62 page
# not found 59화 모범생 (1) 53 page
# not found 59화 모범생 (1) 55 page
# not found 60화 모범생 (2) 71 page
# not found 58화 강박증 (2) 2 page
# not found 58화 강박증 (2) 4 page
# not found 60화 모범생 (2) 75 page
# not found 60화 모범생 (2) 81 page
# not found 60화 모범생 (2) 83 page
# not found 60화 모범생 (2) 87 page
# not found 57화 강박증 (1) 3 page
# not found 60화 모범생 (2) 94 page
# not found 60화 모범생 (2) 99 page
# not found 57화 강박증 (1) 16 page
# not found 57화 강박증 (1) 19 page
# not found 57화 강박증 (1) 27 page
# not found 57화 강박증 (1) 41 page
# not found 56화 면접 (2) 26 page
# not found 56화 면접 (2) 30 page
# not found 57화 강박증 (1) 59 page
# not found 58화 강박증 (2) 80 page
# not found 57화 강박증 (1) 75 page
# not found 57화 강박증 (1) 76 page
# not found 58화 강박증 (2) 93 page
# not found 58화 강박증 (2) 95 page
# not found 58화 강박증 (2) 98 page
# not found 56화 면접 (2) 64 page
# not found 57화 강박증 (1) 87 page
# not found 56화 면접 (2) 66 page
# not found 56화 면접 (2) 69 page
# not found 55화 면접 (1) 6 page
# not found 55화 면접 (1) 10 page
# not found 57화 강박증 (1) 96 page
# not found   27화 모태솔로 53 page
# not found 28화 총알받이 (1) 62 page
# not found 28화 총알받이 (1) 65 page
# not found 28화 총알받이 (1) 66 page
# not found 28화 총알받이 (1) 67 page
# not found   27화 모태솔로 63 page
# not found 28화 총알받이 (1) 70 page
# not found   27화 모태솔로 65 page
# not found   27화 모태솔로 82 page
# not found 25화 인맥도 실력이야 2 page
# not found 25화 인맥도 실력이야 5 page
# not found 26화 전국노예자랑 76 pagenot found 24화 기레기 (3) 2 page
#
# not found 25화 인맥도 실력이야 10 page
# not found 25화 인맥도 실력이야 11 page
# not found 25화 인맥도 실력이야 12 page
# not found 26화 전국노예자랑 84 page
# not found 25화 인맥도 실력이야 19 pagenot found 26화 전국노예자랑 87 page
#
# not found 25화 인맥도 실력이야 20 page
# not found 25화 인맥도 실력이야 23 page
# not found 25화 인맥도 실력이야 28 page
# not found 24화 기레기 (3) 26 page
# not found 25화 인맥도 실력이야 36 page
# not found 25화 인맥도 실력이야 39 page
# not found 25화 인맥도 실력이야 52 page
# not found 25화 인맥도 실력이야 60 page
# not found 23화 기레기 (2) 28 page
# not found 25화 인맥도 실력이야 61 page
# not found 25화 인맥도 실력이야 64 page
# not found 25화 인맥도 실력이야 67 page
# not found 25화 인맥도 실력이야 68 page
# not found 25화 인맥도 실력이야 69 page
# not found 25화 인맥도 실력이야 70 page
# not found 25화 인맥도 실력이야 71 page
# not found 25화 인맥도 실력이야 72 page
# not found 25화 인맥도 실력이야 74 page
# not found 25화 인맥도 실력이야 77 page
# not found 25화 인맥도 실력이야 79 page
# not found 25화 인맥도 실력이야 80 page
# not found 25화 인맥도 실력이야 82 page
# not found 25화 인맥도 실력이야 85 page
# not found 25화 인맥도 실력이야 87 page
# not found 25화 인맥도 실력이야 89 page
# not found 23화 기레기 (2) 57 page
# not found 25화 인맥도 실력이야 90 page
# not found 25화 인맥도 실력이야 92 page
# not found 25화 인맥도 실력이야 93 page
# not found 25화 인맥도 실력이야 94 page
# not found 23화 기레기 (2) 61 page
# not found 25화 인맥도 실력이야 95 page
# not found 25화 인맥도 실력이야 97 page
# not found 23화 기레기 (2) 67 page
# not found 25화 인맥도 실력이야 103 page
# not found 25화 인맥도 실력이야 109 page
# not found 25화 인맥도 실력이야 110 page
# not found 23화 기레기 (2) 81 page
# not found 25화 인맥도 실력이야 125 page
# not found 23화 기레기 (2) 99 page
# not found 25화 인맥도 실력이야 131 page
# not found 25화 인맥도 실력이야 132 page
# not found 21화 차장과의 대화 (2) 4 page
# not found 21화 차장과의 대화 (2) 7 page
# not found 21화 차장과의 대화 (2) 9 page
# not found 22화 기레기 (1) 13 page
# not found 21화 차장과의 대화 (2) 15 page
# not found 21화 차장과의 대화 (2) 19 page
# not found 20화 차장과의 대화 (1) 12 page
# not found 20화 차장과의 대화 (1) 19 page
# not found 21화 차장과의 대화 (2) 28 page
# not found 21화 차장과의 대화 (2) 35 page
# not found 20화 차장과의 대화 (1) 28 page
# not found 20화 차장과의 대화 (1) 31 page
# not found 21화 차장과의 대화 (2) 45 page
# not found 21화 차장과의 대화 (2) 61 page
# not found 21화 차장과의 대화 (2) 62 pagenot found 20화 차장과의 대화 (1) 53 page
#
# not found 22화 기레기 (1) 66 page
# not found 21화 차장과의 대화 (2) 66 page
# not found 21화 차장과의 대화 (2) 69 page
# not found 22화 기레기 (1) 74 page
# not found 21화 차장과의 대화 (2) 79 page
# not found 19화 불안한 조짐 (2) 3 page
# not found   17화 자가당착 1 page
# not found 19화 불안한 조짐 (2) 10 page
# not found 19화 불안한 조짐 (2) 11 page
# not found 19화 불안한 조짐 (2) 14 page
# not found 19화 불안한 조짐 (2) 20 page
# not found 18화 불안한 조짐 (1) 18 page
# not found 19화 불안한 조짐 (2) 25 page
# not found   17화 자가당착 19 page
# not found   17화 자가당착 22 page
# not found 18화 불안한 조짐 (1) 37 page
# not found 19화 불안한 조짐 (2) 43 page
# not found 18화 불안한 조짐 (1) 46 page
# not found   17화 자가당착 40 page
# not found 19화 불안한 조짐 (2) 50 page
# not found 19화 불안한 조짐 (2) 51 page
# not found 19화 불안한 조짐 (2) 52 page
# not found 18화 불안한 조짐 (1) 53 page
# not found 19화 불안한 조짐 (2) 57 page
# not found 19화 불안한 조짐 (2) 60 page
# not found 19화 불안한 조짐 (2) 61 page
# not found 19화 불안한 조짐 (2) 63 page
# not found 19화 불안한 조짐 (2) 65 page
# not found 19화 불안한 조짐 (2) 66 page
# not found   17화 자가당착 60 page
# not found 19화 불안한 조짐 (2) 70 page
# not found 18화 불안한 조짐 (1) 71 pagenot found 19화 불안한 조짐 (2) 71 page
#
# not found 18화 불안한 조짐 (1) 72 page
# not found   17화 자가당착 64 page
# not found 19화 불안한 조짐 (2) 74 page
# not found 18화 불안한 조짐 (1) 75 page
# not found 18화 불안한 조짐 (1) 84 page
# not found 18화 불안한 조짐 (1) 87 pagenot found   16화 잡무셔틀 1 page
#
# not found   17화 자가당착 81 page
# not found   16화 잡무셔틀 6 page
# not found   16화 잡무셔틀 7 page
# not found   17화 자가당착 85 page
# not found   17화 자가당착 91 page
# not found 18화 불안한 조짐 (1) 109 page
# not found   16화 잡무셔틀 25 page
# not found   16화 잡무셔틀 31 page
# not found   17화 자가당착 108 page
# not found   15화 감정이입 2 page
# not found   15화 감정이입 4 page
# not found   16화 잡무셔틀 38 page
# not found   15화 감정이입 15 page
# not found   15화 감정이입 18 page
# not found   17화 자가당착 132 page
# not found   16화 잡무셔틀 55 page
# not found   15화 감정이입 28 page
# not found   16화 잡무셔틀 58 page
# not found   17화 자가당착 139 page
# not found   16화 잡무셔틀 62 page
# not found   15화 감정이입 38 page
# not found   15화 감정이입 40 page
# not found   15화 감정이입 44 page
# not found   17화 자가당착 151 page
# not found   15화 감정이입 49 page
# not found   15화 감정이입 50 page
# not found   16화 잡무셔틀 81 page
# not found   17화 자가당착 168 page
# not found   17화 자가당착 170 page
# not found   17화 자가당착 186 page
# not found  14화 초롱초롱해 12 page
# not found  14화 초롱초롱해 15 page
# not found   15화 감정이입 92 page
# not found   15화 감정이입 96 page
# not found   17화 자가당착 206 page
# not found   17화 자가당착 207 page
# not found   17화 자가당착 208 page
# not found  14화 초롱초롱해 36 page
# not found  14화 초롱초롱해 37 page
# not found   17화 자가당착 219 page
# not found   15화 감정이입 118 page
# not found  14화 초롱초롱해 47 page
# not found   15화 감정이입 125 page
# not found  14화 초롱초롱해 55 page
# not found   17화 자가당착 250 page
# not found   17화 자가당착 253 page
# not found   17화 자가당착 255 page
# not found   17화 자가당착 257 page
# not found   17화 자가당착 259 page
# not found 13화 일탈 (2) 5 page
# not found   17화 자가당착 260 page
# not found   17화 자가당착 262 page
# not found  14화 초롱초롱해 85 page
# not found   17화 자가당착 269 page
# not found   17화 자가당착 272 page
# not found   17화 자가당착 276 page
# not found 13화 일탈 (2) 25 page
# not found   17화 자가당착 282 page
# not found 13화 일탈 (2) 39 page
# not found 13화 일탈 (2) 40 page
# not found    11화 정규직 4 page
# not found 13화 일탈 (2) 45 page
# not found 13화 일탈 (2) 46 page
# not found    11화 정규직 11 page
# not found 13화 일탈 (2) 48 page
# not found 12화 일탈 (1) 16 page
# not found    11화 정규직 23 page
# not found 13화 일탈 (2) 63 page
# not found    11화 정규직 27 page
# not found 13화 일탈 (2) 64 page
# not found    11화 정규직 28 page
# not found 13화 일탈 (2) 70 page
# not found    11화 정규직 37 page
# not found    11화 정규직 47 page
# not found 12화 일탈 (1) 50 page
# not found 12화 일탈 (1) 58 page
# not found    11화 정규직 61 page
# not found 13화 일탈 (2) 100 page
# not found 13화 일탈 (2) 106 page
# not found    11화 정규직 72 page
# not found    11화 정규직 80 page
# not found 12화 일탈 (1) 82 page
# not found 12화 일탈 (1) 101 page
# not found    11화 정규직 100 page
# not found 12화 일탈 (1) 106 page
# not found 12화 일탈 (1) 109 page
# not found 12화 일탈 (1) 112 page
# not found 13화 일탈 (2) 147 pagenot found 12화 일탈 (1) 116 page
#
# not found    11화 정규직 118 page
# not found 13화 일탈 (2) 154 page
# not found 12화 일탈 (1) 125 page
# not found 10화 입사 초의 기억 (2) 3 page
# not found    11화 정규직 134 page
# not found    11화 정규직 141 page
# not found 10화 입사 초의 기억 (2) 14 page
# not found    11화 정규직 143 page
# not found 12화 일탈 (1) 147 page
# not found 10화 입사 초의 기억 (2) 19 page
# not found 10화 입사 초의 기억 (2) 22 page
# not found 12화 일탈 (1) 160 page
# not found 9화 입사 초의 기억 (1) 13 page
# not found 9화 입사 초의 기억 (1) 14 page
# not found 9화 입사 초의 기억 (1) 15 page
# not found 10화 입사 초의 기억 (2) 45 page
# not found 10화 입사 초의 기억 (2) 46 page
# not found 9화 입사 초의 기억 (1) 20 page
# not found 10화 입사 초의 기억 (2) 57 page
# not found 9화 입사 초의 기억 (1) 32 page
# not found 9화 입사 초의 기억 (1) 36 page
# not found 10화 입사 초의 기억 (2) 62 page
# not found 9화 입사 초의 기억 (1) 39 page
# not found 9화 입사 초의 기억 (1) 40 page
# not found 9화 입사 초의 기억 (1) 42 page
# not found 12화 일탈 (1) 198 page
# not found 9화 입사 초의 기억 (1) 47 page
# not found 9화 입사 초의 기억 (1) 50 page
# not found 10화 입사 초의 기억 (2) 76 page
# not found 10화 입사 초의 기억 (2) 77 page
# not found 9화 입사 초의 기억 (1) 52 page
# not found 12화 일탈 (1) 212 page
# not found 12화 일탈 (1) 214 page
# not found 12화 일탈 (1) 217 page
# not found   8화 취업준비생 6 page
# not found 10화 입사 초의 기억 (2) 98 page
# not found 10화 입사 초의 기억 (2) 104 page
# not found 12화 일탈 (1) 235 page
# not found   8화 취업준비생 26 page
# not found     7화 뒷담화 1 page
# not found 12화 일탈 (1) 248 page
# not found 12화 일탈 (1) 250 page
# not found 12화 일탈 (1) 252 page
# not found 12화 일탈 (1) 257 page
# not found     7화 뒷담화 18 page
# not found  6화 불편한 진실 4 page
# not found     7화 뒷담화 27 page
# not found     7화 뒷담화 30 page
# not found  6화 불편한 진실 10 page
# not found     7화 뒷담화 41 page
# not found     7화 뒷담화 44 page
# not found   8화 취업준비생 73 page
# not found   8화 취업준비생 77 page
# not found     7화 뒷담화 59 page
# not found     7화 뒷담화 61 page
# not found     7화 뒷담화 62 page
# not found     7화 뒷담화 71 page
# not found     7화 뒷담화 79 page
# not found  6화 불편한 진실 66 page
# not found  6화 불편한 진실 69 page
# not found      5화 외근 2 page
# not found  6화 불편한 진실 100 page
# not found      5화 외근 28 page
# not found      5화 외근 29 page
# not found      5화 외근 35 page
# not found      4화 갈등 4 page
# not found      5화 외근 40 page
# not found      4화 갈등 15 page
# not found      4화 갈등 28 page
# not found 3화 무지가 낳은 참변 2 page
# not found 3화 무지가 낳은 참변 3 page
# not found 3화 무지가 낳은 참변 14 page
# not found      4화 갈등 59 page
# not found      5화 외근 97 page
# not found      4화 갈등 66 page
# not found      5화 외근 99 page
# not found      5화 외근 100 page
# not found      5화 외근 109 page
# not found 3화 무지가 낳은 참변 57 page
# not found 3화 무지가 낳은 참변 59 page
# not found      4화 갈등 107 page
# not found      4화 갈등 118 page
# not found      4화 갈등 119 page
# not found      4화 갈등 120 page
# not found       프롤로그 5 page

# %%
comment=[]
while not last_queue.empty():
    
    comment.append(last_queue.get())

# %% [markdown]
# ___
# # start of dataframe to excel

# %%
import pandas as pd

# %%
first=pd.DataFrame()
for one_episode in comment:
    data=pd.DataFrame(one_episode)
    first=pd.concat([first,data],ignore_index=True)

# %%
len(comment[0])
# Out:
# 547

# %%
first.to_excel('out_put1.xlsx', sheet_name='sheet1')
# writer = pd.ExcelWriter('out.xlsx', engine='xlsxwriter', options={'strings_to_urls': False})
# df.to_excel(writer)
# [출처] Pandas DataFrame을 엑셀 파일로 내보내기|작성자 onsuu313
